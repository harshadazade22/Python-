# %%
#text file,excel files,XML files,json files

# %% [markdown]
# # To read text files

# %%
#syntax 
#variable_to_store_file=open("path","mode")

# %% [markdown]
# ## "r":read() mode

# %%
file=open(r"C:\Users\admin\Desktop\sejal.txt","r")

# %%
file.read()
# Out:
# 'hello'

# %%
file.close()

# %% [markdown]
# ## To extract set of characters

# %%
file.read(5)     #Read only first 5 char
# Out:
# 'i am '

# %%
file.read(10)
# Out:
# 'i am here '

# %%
# To read content of file we can also use for loop

# %%
for content in file:
    print(content)
# Out:
# i am here to leran python

# %% [markdown]
# # Write mode

# %% [markdown]
# #### With write mode we can also create a new filesand also edit that exiting file

# %%
file=open(r"C:\Users\admin\Desktop\sejal.txt","w")
file.write ("python")
file.close()

# %%
file=open(r"C:\Users\admin\Desktop\sejal.txt","w")
file.write("ipcs global")
file.close()

# %% [markdown]
# # Append mode

# %% [markdown]
# ### To add data to exitsting file

# %%
file=open(r"C:\Users\admin\Desktop\sejal.txt","a")
file.write("\Python")
# Out:
# 7

# %%
file.close()

# %%
file=open(r"C:\Users\admin\Desktop\sejal.txt","a")
file.write("\nData science")
file.close()

# %% [markdown]
# ### "r+" read() and write() mode

# %%
file=open(r"C:\Users\admin\Desktop\sejal.txt","r+")
file.write("\nI am from nagpur")
# Out:
# 17

# %%
file.close()

# %%
with open(r"C:\Users\admin\Desktop\sejal.txt","w")as a:
    a.write("HII")

# %%
l=["this is pune\n","this is nagpur\n","this is mumbai\n"]

# %%
with open(r"C:\Users\admin\Desktop\sejal.txt","w") as a:
    a.writelines(l)

# %% [markdown]
# ## Top read Excel files in python

# %%
import pandas as pd
data=pd.read_excel(r"C:\Users\admin\Downloads\demo_excel.xlsx")
data
# Out:
#       EEID         Full Name                 Job Title       Department  \
# 0   E02387       Emily Davis                Sr. Manger               IT
# 1   E04105     Theodore Dinh       Technical Architect               IT
# 2   E02572      Luna Sanders                  Director          Finance
# 3   E02832   Penelope Jordan  Computer Systems Manager               IT
# 4   E01639         Austin Vo               Sr. Analyst          Finance
# 5   E00644      Joshua Gupta    Account Representative            Sales
# 6   E01550       Ruby Barnes                   Manager               IT
# 7   E04332       Luke Martin                   Analyst          Finance
# 8   E04533     Easton Bailey                   Manager       Accounting
# 9   E03838   Madeline Walker               Sr. Analyst          Finance
# 10  E00591      Savannah Ali                Sr. Manger  Human Resources
# 11  E03344     Camila Rogers         Controls Engineer      Engineering
# ...

# %% [markdown]
# ## Reading csv files using pandas module

# %%
import pandas as pd
data_csv=pd.read_csv(r"C:\Users\admin\Downloads\Excel1 (2).csv")
data_csv
# Out:
#     cellphone_id     brand                 model operating system  \
# 0              0     Apple      iPhone SE (2022)              iOS
# 1              1     Apple        iPhone 13 Mini              iOS
# 2              2     Apple             iPhone 13              iOS
# 3              3     Apple         iPhone 13 Pro              iOS
# 4              4     Apple     iPhone 13 Pro Max              iOS
# 5              5     Apple             iPhone XR              iOS
# 6              6      Asus             Zenfone 8          Android
# 7              7   Samsung            Galaxy A13          Android
# 8              8   Samsung            Galaxy A32          Android
# 9              9   Samsung            Galaxy A53          Android
# 10            10   Samsung            Galaxy S22          Android
# 11            11   Samsung       Galaxy S22 Plus          Android
# 12            12   Samsung      Galaxy S22 Ultra          Android
# ...

# %% [markdown]
# ## Reading csv files using csv module

# %%
import csv

# %%
with open(r"C:\Users\admin\Downloads\Excel1 (2).csv","r") as csvfiles:
    csvreader=csv.reader(csvfiles)

# %%
csvreader

# %% [markdown]
# ## Reading excel files using josn module

# %%
import json

# %%
jsd
